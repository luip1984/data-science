# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

foods = pd.DataFrame(np.random.randn(140,2),columns=['col1','col2'],index=["g1","g2"]*70).reset_index()
print(foods.iloc[0:6,:].head(n=20))
print(foods)
# Out:
#   index      col1      col2
# 0    g1  0.636606 -1.570232
# 1    g2  0.135917  0.365239
# 2    g1 -0.573290 -0.147900
# 3    g2  1.418115 -0.644356
# 4    g1  0.372014 -0.303740
# 5    g2  1.215673 -0.576382
#     index      col1      col2
# 0      g1  0.636606 -1.570232
# 1      g2  0.135917  0.365239
# 2      g1 -0.573290 -0.147900
# 3      g2  1.418115 -0.644356
# 4      g1  0.372014 -0.303740
# 5      g2  1.215673 -0.576382
# 6      g1  1.280807  1.366565
# 7      g2  0.214438  1.013817
# 8      g1 -0.390075 -1.702799
# 9      g2 -2.057830  0.236441
# 10     g1  1.417835 -0.368907
# 11     g2 -1.006962 -0.832867
# 12     g1 -0.016161 -0.925395
# 13     g2  0.620603 -0.866496
# 14     g1 -0.884457 -0.398533
# 15     g2  1.712469 -0.905163
# 16     g1 -1.793914 -0.465512
# 17     g2  0.563000  1.135927
# 18     g1 -0.048304  0.528137
# 19     g2  0.496803  0.144689
# 20     g1  0.330074 -0.890896
# 21     g2 -1.045687  1.553438
# 22     g1  0.612915 -1.633114
# 23     g2 -1.110971 -0.937811
# 24     g1 -0.730920  1.981364
# 25     g2 -0.262588 -0.238718
# 26     g1  1.038696 -0.362408
# 27     g2 -0.223825 -1.062576
# 28     g1  0.588905 -0.219687
# 29     g2 -1.712693 -2.101592
# ..    ...       ...       ...
# 110    g1  0.091764 -0.005642
# 111    g2  0.524969  1.168933
# 112    g1  1.263588  0.881085
# 113    g2 -1.687101 -0.093432
# 114    g1  1.543152  0.433726
# 115    g2  0.472161  1.269151
# 116    g1 -0.146660 -0.978977
# 117    g2 -0.300963  0.966518
# 118    g1  0.445691 -0.355251
# 119    g2  1.058582  1.449933
# 120    g1 -0.735837 -0.409356
# 121    g2 -0.463311 -0.783386
# 122    g1  0.679852 -0.086218
# 123    g2  0.913400  0.020274
# 124    g1 -1.762821  0.666614
# 125    g2 -0.124305  1.430712
# 126    g1 -1.353155 -0.545941
# 127    g2  1.583937 -0.022065
# 128    g1  0.320714  1.248158
# 129    g2  0.050380  1.242960
# 130    g1  0.226695  0.614034
# 131    g2 -0.195212  1.330845
# 132    g1  1.808375  0.726236
# 133    g2 -0.571704  1.271702
# 134    g1 -0.122499  0.588908
# 135    g2 -0.415779  0.690607
# 136    g1  0.377173 -0.746583
# 137    g2 -1.000680 -0.590360
# 138    g1  1.219392 -0.706685
# 139    g2  0.495249 -0.274141
#
# [140 rows x 3 columns]

# %%
print(foods.iloc[0:6]['col1'])
# Out:
# 0    0.636606
# 1    0.135917
# 2   -0.573290
# 3    1.418115
# 4    0.372014
# 5    1.215673
# Name: col1, dtype: float64

# %%
print('Line plots show data over time')
plt.plot(foods.iloc[0:6]['col1'])
plt.show()
# Out:
# Line plots show data over time

# %%
print('Scatterplots show the relationship between two variables.')
plt.scatter(foods['col2'],foods['col1'])
plt.show()
# Out:
# Scatterplots show the relationship between two variables.

# %%
print('Histograms show the distribution of the dataset and any outliers.')
plt.hist(foods['col1'])
plt.show()
# Out:
# Histograms show the distribution of the dataset and any outliers.

# %%
print('QQ plots show how close a variable is to known distribution, and any outliers.')
norm= np.random.normal(0, 1, 140)
#print(norm)
norm.sort()
#print(foods['col1'])
#print(foods['col1'].sort_values())
plt.plot(norm, foods['col1'].sort_values(), ".") 
plt.show()
# Out:
# QQ plots show how close a variable is to known distribution, and any outliers.

# %%
print(foods[foods['index']=='g1'])
# Out:
#     index      col1      col2
# 0      g1  0.636606 -1.570232
# 2      g1 -0.573290 -0.147900
# 4      g1  0.372014 -0.303740
# 6      g1  1.280807  1.366565
# 8      g1 -0.390075 -1.702799
# 10     g1  1.417835 -0.368907
# 12     g1 -0.016161 -0.925395
# 14     g1 -0.884457 -0.398533
# 16     g1 -1.793914 -0.465512
# 18     g1 -0.048304  0.528137
# 20     g1  0.330074 -0.890896
# 22     g1  0.612915 -1.633114
# 24     g1 -0.730920  1.981364
# 26     g1  1.038696 -0.362408
# 28     g1  0.588905 -0.219687
# 30     g1  0.146253 -0.174480
# 32     g1 -0.379685 -0.530679
# 34     g1 -0.584565  1.031436
# 36     g1  0.286261  0.752164
# 38     g1  1.170867  0.256834
# 40     g1 -1.008617  1.479593
# 42     g1 -1.287879 -0.048372
# 44     g1 -1.802509 -0.416658
# 46     g1  2.140688 -0.141821
# 48     g1  0.211394 -2.392026
# 50     g1 -0.303010  0.723735
# 52     g1  1.588837  0.282978
# 54     g1 -0.894238 -0.221030
# 56     g1  0.940686 -0.313469
# 58     g1 -0.639677  0.741912
# ..    ...       ...       ...
# 80     g1 -0.884977  1.222296
# 82     g1 -1.013942 -0.644392
# 84     g1 -2.251491 -0.683586
# 86     g1 -0.143540 -0.547881
# 88     g1 -1.545734  0.590244
# 90     g1  0.305503  0.600122
# 92     g1 -0.526481 -0.052189
# 94     g1 -1.491642 -2.777011
# 96     g1  0.808021  0.766477
# 98     g1 -1.183131  1.202577
# 100    g1  0.851175  0.671959
# 102    g1  0.342479 -1.034953
# 104    g1  1.278442 -0.340173
# 106    g1  1.514792 -3.167802
# 108    g1 -0.763587  1.403140
# 110    g1  0.091764 -0.005642
# 112    g1  1.263588  0.881085
# 114    g1  1.543152  0.433726
# 116    g1 -0.146660 -0.978977
# 118    g1  0.445691 -0.355251
# 120    g1 -0.735837 -0.409356
# 122    g1  0.679852 -0.086218
# 124    g1 -1.762821  0.666614
# 126    g1 -1.353155 -0.545941
# 128    g1  0.320714  1.248158
# 130    g1  0.226695  0.614034
# 132    g1  1.808375  0.726236
# 134    g1 -0.122499  0.588908
# 136    g1  0.377173 -0.746583
# 138    g1  1.219392 -0.706685
#
# [70 rows x 3 columns]

# %%
print('Boxplots are used to compare groups and to identify differences in variance, as well as outliers.')
plt.boxplot([foods[foods['index']=='g1']['col1'],foods[foods['index']=='g2']['col1']])
plt.show()
# Out:
# Boxplots are used to compare groups and to identify differences in variance, as well as outliers.
